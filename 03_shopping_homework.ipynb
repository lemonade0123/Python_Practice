# %% [markdown]
# 3-2. 네이버 쇼핑 검색 API 호출하기

# %%
import requests
from pprint import pprint
from dotenv import load_dotenv
import os

# .env 파일 로드
load_dotenv()

# 공통 headers 생성 함수
def get_headers():
    return {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
        'X-Naver-Client-Id': os.getenv('NAVER_CLIENT_ID'),
        'X-Naver-Client-Secret': os.getenv('NAVER_CLIENT_SECRET')
    }

# 네이버 쇼핑 검색 함수
def search_shops(query):
    url = 'https://openapi.naver.com/v1/search/shop.json'
    payload = {
        'query': query,
        'display': 50,
        'sort': 'sim'
    }

    headers = get_headers()
    res = requests.get(url, params=payload, headers=headers)
    
    if res.ok:
        return res.json().get('items', [])
    else:
        print(f"Error fetching book data: {res.status_code}")
        return []

# %%
import json
import os

def save_shops_to_json(book_list, filepath='data/shops.json'):
    os.makedirs(os.path.dirname(filepath), exist_ok=True)
    with open(filepath, 'w', encoding='utf-8') as f:
        json.dump(book_list, f, ensure_ascii=False, indent=4)
    print(f" 쇼핑핑 목록이 {filepath}에 저장되었습니다.")
    
if __name__ == '__main__':
    query = "가디건"
    shops = search_shops(query)
    save_shops_to_json(shops)
# Out:
#  쇼핑핑 목록이 data/shops.json에 저장되었습니다.

# %% [markdown]
# 2. shops.json 파일을 Pandas DataFrame로 저장하기

# %%
import pandas as pd
import json

def load_shops_json_to_dataframe(filepath='data/shops.json'):
    with open(filepath, 'r', encoding='utf-8') as f:
        shops_data = json.load(f)
    
    df = pd.DataFrame(shops_data)
    print(f" {filepath} 파일을 DataFrame으로 불러왔습니다.")
    return df

if __name__ == '__main__':
    df_shops = load_shops_json_to_dataframe()
    print(df_shops.head())  # DataFrame 내용 확인
# Out:
#  data/shops.json 파일을 DataFrame으로 불러왔습니다.
#                                                title  \
# 0  백화점3-5일배송 폴로 <b>가디건</b> 걸즈 걸스 랄프로렌 꽈배기 블랙 화이트 ...
# 1  봄 가을 간절기 라운드 루즈핏 크롭 <b>가디건</b> 레드 그린 핑크 화이트 블랙...
# 2  부드러운 캐시미어 크롭 <b>가디건</b> 숏 라운드 니트<b>가디건</b> 여성 ...
# 3  [백화점3-5일배송] 폴로 <b>가디건</b> 니트 걸즈 랄프로렌 블랙 화이트 핑크...
# 4  [국내발송 + 선물포장] 폴로 랄프로렌 여아 아기 코튼 베이비 <b>가디건</b> ...
#
#                                                 link  \
# 0  https://smartstore.naver.com/main/products/667...
# 1  https://smartstore.naver.com/main/products/546...
# 2  https://smartstore.naver.com/main/products/482...
# 3  https://smartstore.naver.com/main/products/845...
# 4  https://smartstore.naver.com/main/products/945...
#
#                                                image lprice hprice mallName  \
# 0  https://shopping-phinf.pstatic.net/main_842166...  64900           나우인뉴욕
# 1  https://shopping-phinf.pstatic.net/main_830114...  19900           ARUMY
# 2  https://shopping-phinf.pstatic.net/main_823726...  18900            코이블리
# 3  https://shopping-phinf.pstatic.net/main_859949...  63900         트위티 155
# 4  https://shopping-phinf.pstatic.net/main_870040...  69000           리틀데이즈
#
#      productId productType   brand   maker category1 category2 category3  \
# 0  84216650390           2  폴로랄프로렌  폴로랄프로렌      패션의류      여성의류       카디건
# 1  83011442056           2                      패션의류      여성의류       카디건
# 2  82372678315           2                      패션의류      여성의류       카디건
# 3  85994962324           2  폴로랄프로렌  폴로랄프로렌      패션의류      여성의류       카디건
# 4  87004045841           2  폴로랄프로렌  폴로랄프로렌     출산/육아     유아동의류       카디건
#
#   category4
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# 3. 질문 : 검색어로 찾은 Shop의 상품 목록 출력하기

# %%
import json
import os

# 쇼핑 목록 출력 함수
def print_shops(shops):
    for idx, shop in enumerate(shops, 1):
        print(f"\n{idx}. title: {shop.get('title')}")
        print(f"link: {shop.get('link')}")
        print(f"image: {shop.get('image')}")
        print(f"lprice: {shop.get('lprice')}원")
        print(f"hprice: {shop.get('hprice')}원")
        print(f"mallName: {shop.get('mallName')}")
        print(f"brand: {shop.get('brand')}")
        desc = shop.get('description', '')
        

# JSON 파일을 읽어서 쇼핑 목록 출력
def load_and_print_shops(filepath='data/shops.json'):
    if not os.path.exists(filepath):
        print(f"No File: {filepath}")
        return

    with open(filepath, 'r', encoding='utf-8') as f:
        shops = json.load(f)

    if shops:
        print_shops(shops)
    else:
        print("Empty.")
        
if __name__ == '__main__':
    load_and_print_shops()
# Out:
# 1. title: 백화점3-5일배송 폴로 <b>가디건</b> 걸즈 걸스 랄프로렌 꽈배기 블랙 화이트 핑크 헌터네이비XL
# link: https://smartstore.naver.com/main/products/6672150068
# image: https://shopping-phinf.pstatic.net/main_8421665/84216650390.13.jpg
# lprice: 64900원
# hprice: 원
# mallName: 나우인뉴욕
# brand: 폴로랄프로렌
#
# 2. title: 봄 가을 간절기 라운드 루즈핏 크롭 <b>가디건</b> 레드 그린 핑크 화이트 블랙 옐로우
# link: https://smartstore.naver.com/main/products/5466947569
# image: https://shopping-phinf.pstatic.net/main_8301144/83011442056.2.jpg
# lprice: 19900원
# hprice: 원
# mallName: ARUMY
# brand:
#
# 3. title: 부드러운 캐시미어 크롭 <b>가디건</b> 숏 라운드 니트<b>가디건</b> 여성 <b>가디건</b> 봄 간절기 레드 핑크
# link: https://smartstore.naver.com/main/products/4828155463
# image: https://shopping-phinf.pstatic.net/main_8237267/82372678315.3.jpg
# lprice: 18900원
# hprice: 원
# mallName: 코이블리
# brand:
#
# 4. title: [백화점3-5일배송] 폴로 <b>가디건</b> 니트 걸즈 랄프로렌 블랙 화이트 핑크 헌터네이비XL L
# link: https://smartstore.naver.com/main/products/8450462001
# image: https://shopping-phinf.pstatic.net/main_8599496/85994962324.3.jpg
# lprice: 63900원
# hprice: 원
# mallName: 트위티 155
# brand: 폴로랄프로렌
#
# 5. title: [국내발송 + 선물포장] 폴로 랄프로렌 여아 아기 코튼 베이비 <b>가디건</b> 핑크 옐로우 화이트
# link: https://smartstore.naver.com/main/products/9459545518
# image: https://shopping-phinf.pstatic.net/main_8700404/87004045841.1.jpg
# lprice: 69000원
# hprice: 원
# mallName: 리틀데이즈
# brand: 폴로랄프로렌
#
# 6. title: 10COLOR 여성 봄 비비드컬러 라운드 슬릿넥 크롭 니트 그린 핑크<b>가디건</b>
# link: https://smartstore.naver.com/main/products/9959540751
# image: https://shopping-phinf.pstatic.net/main_8750404/87504043024.jpg
# lprice: 24900원
# hprice: 원
# mallName: ARUMY
# brand:
#
# 7. title: [백화점] 폴로 <b>가디건</b> 걸즈 케이블 꽈배기 니트
# link: https://smartstore.naver.com/main/products/11107384300
# image: https://shopping-phinf.pstatic.net/main_8865189/88651894622.2.jpg
# lprice: 69000원
# hprice: 원
# mallName: 세컨찬스라이프
# brand: 폴로랄프로렌
#
# 8. title: 꼼데가르송 기본와펜 <b>가디건</b> 여성용
# link: https://smartstore.naver.com/main/products/4741606965
# image: https://shopping-phinf.pstatic.net/main_8228612/82286128596.6.jpg
# lprice: 254390원
# hprice: 원
# mallName: 레이바쿠
# brand: 꼼데가르송
#
# 9. title: 제너럴아이디어 WOMAN GNRL 에센셜 베이직 <b>카디건</b> 11COL WBD3L04503
# link: https://search.shopping.naver.com/catalog/53287208769
# image: https://shopping-phinf.pstatic.net/main_5328720/53287208769.20250302141747.jpg
# lprice: 32400원
# hprice: 원
# mallName: 네이버
# brand: 제너럴아이디어
#
# 10. title: 메종키츠네 <b>가디건</b> 베이비폭스 폭스헤드 더블폭스 칠랙스 [당일출고]
# link: https://smartstore.naver.com/main/products/5302659122
# image: https://shopping-phinf.pstatic.net/main_8284715/82847151528.5.jpg
# lprice: 267000원
# hprice: 원
# mallName: 브랜드리퍼블릭
# brand: 메종키츠네
#
# 11. title: (8컬러)폴로랄프로렌 피마코튼 여성 <b>가디건</b>
# link: https://smartstore.naver.com/main/products/3427657202
# image: https://shopping-phinf.pstatic.net/main_8097217/80972174298.23.jpg
# lprice: 209000원
# hprice: 원
# mallName: 바이찬스
# brand: 폴로
#
# 12. title: [미국 백화점] 폴로 <b>가디건</b> 걸스 걸즈 랄프로렌 꽈배기 케이블 니트 <b>가디건</b> 네이비 블랙 핑크 화이트 L XL
# link: https://smartstore.naver.com/main/products/5766048400
# image: https://shopping-phinf.pstatic.net/main_8331054/83310547814.5.jpg
# lprice: 59900원
# hprice: 원
# mallName: 뉴욕바잉
# brand: 폴로랄프로렌
#
# 13. title: 여자 보풀없는 캐시미어 비스코스 니트 여성 라운드 <b>가디건</b> 인디핑크 병원 간호 사무실
# link: https://smartstore.naver.com/main/products/5391580059
# image: https://shopping-phinf.pstatic.net/main_8293607/82936073452.3.jpg
# lprice: 29900원
# hprice: 원
# mallName: 지읒이응
# brand:
#
# 14. title: H&amp;M HM 파인 니트 <b>가디건</b> 0579541001
# link: https://search.shopping.naver.com/catalog/51781610172
# image: https://shopping-phinf.pstatic.net/main_5178161/51781610172.20241205202656.jpg
# lprice: 17512원
# hprice: 원
# mallName: 네이버
# brand: H&M
#
# 15. title: 레이어드<b>가디건</b> 캐시미어<b>가디건</b> 여자봄<b>가디건</b> 사무실
# link: https://smartstore.naver.com/main/products/10064618231
# image: https://shopping-phinf.pstatic.net/main_8760912/87609120854.1.jpg
# lprice: 29800원
# hprice: 원
# mallName: 미드시티 여성니트
# brand:
#
# 16. title: 남자<b>가디건</b> 울 라운드 캐시미어 오버핏 하찌 니트 커플<b>가디건</b> 봄 가을
# link: https://smartstore.naver.com/main/products/5290981221
# image: https://shopping-phinf.pstatic.net/main_8283547/82835473460.11.jpg
# lprice: 39800원
# hprice: 원
# mallName: 왓위웨어
# brand:
#
# 17. title: 시스루 얇은 린넨 루즈핏 니트 여름 여성 <b>가디건</b> (올타임)
# link: https://smartstore.naver.com/main/products/5592080655
# image: https://shopping-phinf.pstatic.net/main_8313657/83136576950.2.jpg
# lprice: 23900원
# hprice: 원
# mallName: 고고하니
# brand:
#
# 18. title: [국내배송] 꼼데가르송 <b>가디건</b> 기본와펜 여성/남성용
# link: https://smartstore.naver.com/main/products/7945338110
# image: https://shopping-phinf.pstatic.net/main_8548983/85489838433.6.jpg
# lprice: 315800원
# hprice: 원
# mallName: 브랜드사는이쁜언니
# brand: 꼼데가르송
#
# 19. title: (당일) 프리티영띵 뉴 페블 골지 <b>가디건</b> PYT 프영띵 떠유니
# link: https://smartstore.naver.com/main/products/9044880794
# image: https://shopping-phinf.pstatic.net/main_8658938/86589381117.3.jpg
# lprice: 42000원
# hprice: 원
# mallName: ttoyuni
# brand:
#
# 20. title: [우체국당일발송] 폴로 걸즈 <b>가디건</b> XL / 폴로 랄프로렌 걸즈 케이블 니트 꽈배기 <b>가디건</b>
# link: https://smartstore.naver.com/main/products/6629506201
# image: https://shopping-phinf.pstatic.net/main_8417400/84174006523.jpg
# lprice: 115000원
# hprice: 원
# mallName: 트렌드홀릭
# brand: 폴로랄프로렌
#
# 21. title: [QR인증백화점] 폴로 <b>가디건</b> 걸즈 여성 케이블 꽈배기 니트
# link: https://smartstore.naver.com/main/products/11222372847
# image: https://shopping-phinf.pstatic.net/main_8876688/88766883178.3.jpg
# lprice: 68700원
# hprice: 원
# mallName: 부스더샵
# brand: 폴로랄프로렌
#
# 22. title: 드온도 노튼 캐시미어 <b>가디건</b> 봄 스프링 라운드 니트 deondo
# link: https://smartstore.naver.com/main/products/9971634198
# image: https://shopping-phinf.pstatic.net/main_8751613/87516136471.1.jpg
# lprice: 49500원
# hprice: 원
# mallName: 루나드엘
# brand:
#
# 23. title: 포인즈 부드럽고 포근해 얇은 니트 울 오버핏 <b>가디건</b> 여성 <b>가디건</b> 겨울 봄
# link: https://smartstore.naver.com/main/products/5194780033
# image: https://shopping-phinf.pstatic.net/main_8273930/82739301366.2.jpg
# lprice: 24800원
# hprice: 원
# mallName: 베이지블랑.
# brand:
#
# 24. title: 예가체프 R 파인울 <b>가디건</b>
# link: https://smartstore.naver.com/main/products/11333309394
# image: https://shopping-phinf.pstatic.net/main_8887781/88877819725.jpg
# lprice: 43700원
# hprice: 원
# mallName: 사색
# brand: 사색
#
# 25. title: 폴로 랄프로렌 케이블 <b>가디건</b> 보이즈 (3컬러)
# link: https://smartstore.naver.com/main/products/9180341475
# image: https://shopping-phinf.pstatic.net/main_8672484/86724841798.5.jpg
# lprice: 129000원
# hprice: 원
# mallName: 포니홀릭
# brand: 폴로랄프로렌
#
# 26. title: 꼼데가르송 꼼데 <b>가디건</b> 여성 남성 니트
# link: https://smartstore.naver.com/main/products/5924539032
# image: https://shopping-phinf.pstatic.net/main_8346903/83469038520.1.jpg
# lprice: 329000원
# hprice: 원
# mallName: 도쿄루꼬
# brand: 꼼데가르송
#
# 27. title: 톰브라운 <b>가디건</b> 울 밀라노 스티치 MKC002A
# link: https://smartstore.naver.com/main/products/6566315211
# image: https://shopping-phinf.pstatic.net/main_8411081/84110815544.4.jpg
# lprice: 809000원
# hprice: 원
# mallName: 버닝웨어
# brand: 톰브라운
#
# 28. title: 꼼데가르송 기본와펜 <b>가디건</b> 남성용
# link: https://smartstore.naver.com/main/products/4727598933
# image: https://shopping-phinf.pstatic.net/main_8227212/82272120255.2.jpg
# lprice: 254300원
# hprice: 원
# mallName: 레이바쿠
# brand: 꼼데가르송
#
# 29. title: 벤시몽 여성 코튼 블렌드 케이블 <b>가디건</b> 3종
# link: https://search.shopping.naver.com/catalog/53232763110
# image: https://shopping-phinf.pstatic.net/main_5323276/53232763110.20250226185010.jpg
# lprice: 44910원
# hprice: 원
# mallName: 네이버
# brand: 벤시몽
#
# 30. title: [백화점] 폴로 랄프로렌 남자 코튼 브이넥 <b>가디건</b> (4컬러)
# link: https://smartstore.naver.com/main/products/9097681985
# image: https://shopping-phinf.pstatic.net/main_8664218/86642182308.1.jpg
# lprice: 159000원
# hprice: 원
# mallName: 포니홀릭
# brand: 폴로랄프로렌
#
# 31. title: 티블러썸 결혼식 하객룩 진주단추 <b>가디건</b> 봄 퍼프 니트 여성 금장 크롭 <b>가디건</b> 6color
# link: https://smartstore.naver.com/main/products/7984870784
# image: https://shopping-phinf.pstatic.net/main_8552937/85529371107.jpg
# lprice: 27000원
# hprice: 원
# mallName: 건강한생활82
# brand:
#
# 32. title: 유니클로 UV PROTECTION 크루넥 여성 <b>가디건</b> 자외선차단 봄 간절기 빅사이즈
# link: https://smartstore.naver.com/main/products/10061021121
# image: https://shopping-phinf.pstatic.net/main_8760552/87605523696.jpg
# lprice: 49800원
# hprice: 원
# mallName: 더헤르츠
# brand: 유니클로
#
# 33. title: 제너럴아이디어 GENERALIDEA WOMAN 에센셜 크루넥 <b>가디건</b> 4COL WBD3L04501
# link: https://search.shopping.naver.com/catalog/49541497760
# image: https://shopping-phinf.pstatic.net/main_4954149/49541497760.20250211235224.jpg
# lprice: 31416원
# hprice: 원
# mallName: 네이버
# brand: 제너럴아이디어
#
# 34. title: 라코스테 남성 베이직 V넥 방모 <b>가디건</b> AH560E-54N
# link: https://search.shopping.naver.com/catalog/49714141886
# image: https://shopping-phinf.pstatic.net/main_4971414/49714141886.20240827160222.jpg
# lprice: 80100원
# hprice: 원
# mallName: 네이버
# brand: 라코스테
#
# 35. title: 비비안웨스트우드 여성 베아 울 실크 <b>가디건</b> 1803001Z
# link: https://search.shopping.naver.com/catalog/43475137325
# image: https://shopping-phinf.pstatic.net/main_4347513/43475137325.20240409151632.jpg
# lprice: 28070원
# hprice: 원
# mallName: 네이버
# brand: 비비안웨스트우드
#
# 36. title: 비비안웨스트우드 <b>가디건</b> 여성 화이트라벨 선물패키지
# link: https://smartstore.naver.com/main/products/6260556498
# image: https://shopping-phinf.pstatic.net/main_8380505/83805058987.6.jpg
# lprice: 261000원
# hprice: 원
# mallName: 브랜드리퍼블릭
# brand: 비비안웨스트우드
#
# 37. title: 벤시몽 여성 케이블 니트 <b>가디건</b> 3종
# link: https://search.shopping.naver.com/catalog/53373694627
# image: https://shopping-phinf.pstatic.net/main_5337369/53373694627.20250315071223.jpg
# lprice: 37650원
# hprice: 원
# mallName: 네이버
# brand: 벤시몽
#
# 38. title: 쉬즈미스 메탈 라운드넥 니트 <b>가디건</b> SSKCDO31060
# link: https://search.shopping.naver.com/catalog/49625464649
# image: https://shopping-phinf.pstatic.net/main_4962546/49625464649.20241026105733.jpg
# lprice: 36910원
# hprice: 원
# mallName: 네이버
# brand: 쉬즈미스
#
# 39. title: 메종키츠네 <b>가디건</b> 폭스헤드 트리컬러 베이비폭스 볼드폭스
# link: https://smartstore.naver.com/main/products/4893542136
# image: https://shopping-phinf.pstatic.net/main_8243806/82438065670.9.jpg
# lprice: 259000원
# hprice: 원
# mallName: 브랜드리퍼블릭
# brand: 메종키츠네
#
# 40. title: 꼼데가르송 화이트와펜 <b>가디건</b> 여성용
# link: https://smartstore.naver.com/main/products/4368011188
# image: https://shopping-phinf.pstatic.net/main_8191253/81912533349.2.jpg
# lprice: 292800원
# hprice: 원
# mallName: 레이바쿠
# brand: 꼼데가르송
#
# 41. title: 리스트 라운드넥 버튼 니트 <b>가디건</b> TSKCDO72010
# link: https://search.shopping.naver.com/catalog/51143733510
# image: https://shopping-phinf.pstatic.net/main_5114373/51143733510.20241103013933.jpg
# lprice: 23000원
# hprice: 원
# mallName: 네이버
# brand: 리스트
#
# 42. title: 라코스테 남성 피케 조직 V넥 울<b>가디건</b> AH697E-54N
# link: https://search.shopping.naver.com/catalog/50705955349
# image: https://shopping-phinf.pstatic.net/main_5070595/50705955349.20241022102118.jpg
# lprice: 174090원
# hprice: 원
# mallName: 네이버
# brand: 라코스테
#
# 43. title: 머핀 도톰 루즈핏 숄 울니트 롱<b>가디건</b> 3col 봄 겨울 오버핏 고급원사 노카라 제이플로우
# link: https://smartstore.naver.com/main/products/8103674313
# image: https://shopping-phinf.pstatic.net/main_8564817/85648174636.jpg
# lprice: 41800원
# hprice: 원
# mallName: 제이플로우
# brand: 제이플로우
#
# 44. title: 셀렙샵에디션 알파카 캔디 니트<b>가디건</b>
# link: https://search.shopping.naver.com/catalog/53020866519
# image: https://shopping-phinf.pstatic.net/main_5302086/53020866519.20250227110208.jpg
# lprice: 53900원
# hprice: 원
# mallName: 네이버
# brand: 셀렙샵에디션
#
# 45. title: 카렌 여름 가을 간절기 여자 아기<b>가디건</b> 유아<b>가디건</b> 3개월 6개월 9개월 돌아기
# link: https://smartstore.naver.com/main/products/4901850589
# image: https://shopping-phinf.pstatic.net/main_8244637/82446374164.jpg
# lprice: 19800원
# hprice: 원
# mallName: 로이앤한나
# brand:
#
# 46. title: 루즈핏 캐시미어 브이넥<b>가디건</b> 숏 크롭 여성<b>가디건</b> 니트<b>가디건</b> 봄 간절기 레드 핑크 블랙
# link: https://smartstore.naver.com/main/products/4382440024
# image: https://shopping-phinf.pstatic.net/main_8192696/81926962185.1.jpg
# lprice: 18900원
# hprice: 원
# mallName: 코이블리
# brand:
#
# 47. title: 모르간 24FW 반팔 울 니트<b>가디건</b> 3종 88
# link: https://search.shopping.naver.com/catalog/50504636053
# image: https://shopping-phinf.pstatic.net/main_5050463/50504636053.20240926182452.jpg
# lprice: 37160원
# hprice: 원
# mallName: 네이버
# brand: 모르간
#
# 48. title: 타미힐피거 <b>가디건</b> 여자 베이직 코튼 비스코스 라운드넥 니트 티셔츠
# link: https://smartstore.naver.com/main/products/8472076845
# image: https://shopping-phinf.pstatic.net/main_8601657/86016577168.1.jpg
# lprice: 69000원
# hprice: 원
# mallName: 빨간단풍 구매대행
# brand: 타미힐피거
#
# 49. title: 메종키츠네 <b>가디건</b> 폭스헤드 더블폭스 베이비폭스
# link: https://smartstore.naver.com/main/products/5298295067
# image: https://shopping-phinf.pstatic.net/main_8284278/82842787416.6.jpg
# lprice: 298000원
# hprice: 원
# mallName: 버닝웨어
# brand: 메종키츠네
#
# 50. title: [백화점당일출고] 타미 힐피거 남성 풀 집업 코튼 니트 남자 <b>가디건</b>
# link: https://smartstore.naver.com/main/products/9454099287
# image: https://shopping-phinf.pstatic.net/main_8699859/86998599609.2.jpg
# lprice: 65900원
# hprice: 원
# mallName: 나우인뉴욕
# brand: 타미힐피거

# %% [markdown]
# 4. 질문 : 검색어로 찾은 Shop의 상품 목록 중에서 가격이 50,000원 이하인 상품만 출력하기

# %%
import pandas as pd
import json

def print_filtered_shops(filepath='data/shops.json'):
    if not os.path.exists(filepath):
        print(f"No File: {filepath}")
        return

    with open(filepath, 'r', encoding='utf-8') as f:
        shops = json.load(f)

    # JSON → DataFrame
    df = pd.DataFrame(shops)

    # lprice를 숫자로 변환
    df['lprice'] = pd.to_numeric(df['lprice'], errors='coerce')

    # 가격 5만원 이하 필터링
    filtered_df = df[df['lprice'] <= 50000]

    # 필요한 컬럼만 선택
    filtered_df = filtered_df[['brand', 'lprice', 'mallName', 'link']]

    # 오름차순 정렬
    filtered_df = filtered_df.sort_values(by='lprice', ascending=True)

    # 인덱스 초기화
    filtered_df = filtered_df.reset_index(drop=True)

    # 결과 출력
    print(filtered_df)

# 실행 예시
if __name__ == '__main__':
    print_filtered_shops()
# Out:
#        brand  lprice   mallName  \
# 0        H&M   17512        네이버
# 1              18900       코이블리
# 2              18900       코이블리
# 3              19800      로이앤한나
# 4              19900      ARUMY
# 5        리스트   23000        네이버
# 6              23900       고고하니
# 7              24800     베이지블랑.
# 8              24900      ARUMY
# 9              27000    건강한생활82
# 10  비비안웨스트우드   28070        네이버
# 11             29800  미드시티 여성니트
# 12             29900       지읒이응
# 13   제너럴아이디어   31416        네이버
# 14   제너럴아이디어   32400        네이버
# 15      쉬즈미스   36910        네이버
# 16       모르간   37160        네이버
# 17       벤시몽   37650        네이버
# 18             39800       왓위웨어
# 19     제이플로우   41800      제이플로우
# 20             42000    ttoyuni
# 21        사색   43700         사색
# 22       벤시몽   44910        네이버
# 23             49500       루나드엘
# 24      유니클로   49800       더헤르츠
#
#                                                  link
# 0   https://search.shopping.naver.com/catalog/5178...
# 1   https://smartstore.naver.com/main/products/482...
# 2   https://smartstore.naver.com/main/products/438...
# 3   https://smartstore.naver.com/main/products/490...
# 4   https://smartstore.naver.com/main/products/546...
# 5   https://search.shopping.naver.com/catalog/5114...
# 6   https://smartstore.naver.com/main/products/559...
# 7   https://smartstore.naver.com/main/products/519...
# 8   https://smartstore.naver.com/main/products/995...
# 9   https://smartstore.naver.com/main/products/798...
# 10  https://search.shopping.naver.com/catalog/4347...
# 11  https://smartstore.naver.com/main/products/100...
# 12  https://smartstore.naver.com/main/products/539...
# 13  https://search.shopping.naver.com/catalog/4954...
# 14  https://search.shopping.naver.com/catalog/5328...
# 15  https://search.shopping.naver.com/catalog/4962...
# 16  https://search.shopping.naver.com/catalog/5050...
# 17  https://search.shopping.naver.com/catalog/5337...
# 18  https://smartstore.naver.com/main/products/529...
# 19  https://smartstore.naver.com/main/products/810...
# 20  https://smartstore.naver.com/main/products/904...
# 21  https://smartstore.naver.com/main/products/113...
# 22  https://search.shopping.naver.com/catalog/5323...
# 23  https://smartstore.naver.com/main/products/997...
# 24  https://smartstore.naver.com/main/products/100...

# %% [markdown]
# 5. 질문 : 검색어로 찾은 Shop의 상품 목록 중에서 특정 쇼핑몰 상품만 출력하기

# %%
import pandas as pd
import json
import os

def print_shops_by_mall(mall_name, filepath='data/shops.json'):
    if not os.path.exists(filepath):
        print(f"No File: {filepath}")
        return

    with open(filepath, 'r', encoding='utf-8') as f:
        shops = json.load(f)

    df = pd.DataFrame(shops)

    # lprice를 숫자로 변환
    df['lprice'] = pd.to_numeric(df['lprice'], errors='coerce')

    # 특정 쇼핑몰 필터링
    df_filtered = df[df['mallName'] == mall_name]

    # 컬럼 순서 보장 후 slicing (lprice부터 brand까지)
    columns = list(df_filtered.columns)
    if 'lprice' in columns and 'brand' in columns:
        start_idx = columns.index('lprice')
        end_idx = columns.index('brand') + 1
        df_filtered = df_filtered.iloc[:, start_idx:end_idx]
    else:
        print("'lprice' 또는 'brand' 컬럼이 없습니다.")
        return

    # 정렬 + 인덱스 초기화
    df_filtered = df_filtered.sort_values(by='lprice', ascending=True).reset_index(drop=True)

    # 출력
    print(df_filtered)

#  예시 실행
if __name__ == '__main__':
    print_shops_by_mall('네이버')
# Out:
#     lprice hprice mallName    productId productType     brand
# 0    17512             네이버  51781610172           1       H&M
# 1    23000             네이버  51143733510           1       리스트
# 2    28070             네이버  43475137325           1  비비안웨스트우드
# 3    31416             네이버  49541497760           1   제너럴아이디어
# 4    32400             네이버  53287208769           1   제너럴아이디어
# 5    36910             네이버  49625464649           1      쉬즈미스
# 6    37160             네이버  50504636053           1       모르간
# 7    37650             네이버  53373694627           1       벤시몽
# 8    44910             네이버  53232763110           1       벤시몽
# 9    53900             네이버  53020866519           1    셀렙샵에디션
# 10   80100             네이버  49714141886           1      라코스테
# 11  174090             네이버  50705955349           1      라코스테
