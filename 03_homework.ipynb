# %% [markdown]
# 3-1. 네이버 책 검색 API 호출하기

# %%
import requests
from pprint import pprint
from dotenv import load_dotenv
import os

# .env 파일 로드
load_dotenv()

# 공통 headers 생성 함수
def get_headers():
    return {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
        'X-Naver-Client-Id': os.getenv('NAVER_CLIENT_ID'),
        'X-Naver-Client-Secret': os.getenv('NAVER_CLIENT_SECRET')
    }

# 네이버 책 검색 함수
def search_books(query):
    url = 'https://openapi.naver.com/v1/search/book.json'
    params = {
        'query': query,
        'display': 50,
        'sort': 'sim'
    }

    headers = get_headers()
    res = requests.get(url, params=params, headers=headers)
    
    if res.ok:
        return res.json().get('items', [])
    else:
        print(f"Error fetching book data: {res.status_code}")
        return []

# %% [markdown]
# 1. 질문 :  검색어로  찾은  책 목록을 json 파일로 저장하기

# %%
import json
import os

def save_books_to_json(book_list, filepath='data/books.json'):
    os.makedirs(os.path.dirname(filepath), exist_ok=True)
    with open(filepath, 'w', encoding='utf-8') as f:
        json.dump(book_list, f, ensure_ascii=False, indent=4)
    print(f" 책 목록이 {filepath}에 저장되었습니다.")
    
if __name__ == '__main__':
    query = "파이썬"
    books = search_books(query)
    save_books_to_json(books)
# Out:
#  책 목록이 data/books.json에 저장되었습니다.

# %% [markdown]
# 2. books.json 파일을 Pandas DataFrame로 저장하기

# %%
import pandas as pd
import json

def load_books_json_to_dataframe(filepath='data/books.json'):
    with open(filepath, 'r', encoding='utf-8') as f:
        books_data = json.load(f)
    
    df = pd.DataFrame(books_data)
    print(f" {filepath} 파일을 DataFrame으로 불러왔습니다.")
    return df

if __name__ == '__main__':
    df_books = load_books_json_to_dataframe()
    print(df_books.head())  # DataFrame 내용 확인
# Out:
#  data/books.json 파일을 DataFrame으로 불러왔습니다.
#                                                title  \
# 0  혼자 만들면서 공부하는 파이썬 (37개 라이브러리와 API로 보고서, 차트, 게임,...
# 1               혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)
# 2           Do it! 점프 투 파이썬 (중학생도 첫날부터 실습하는 초고속 입문서)
# 3     밑바닥부터 시작하는 딥러닝 1(리마스터판) (파이썬으로 익히는 딥러닝 이론과 구현)
# 4                                                파이썬
#
#                                                 link  \
# 0  https://search.shopping.naver.com/book/catalog...
# 1  https://search.shopping.naver.com/book/catalog...
# 2  https://search.shopping.naver.com/book/catalog...
# 3  https://search.shopping.naver.com/book/catalog...
# 4  https://search.shopping.naver.com/book/catalog...
#
#                                                image  author discount  \
# 0  https://shopping-phinf.pstatic.net/main_528593...     문현일    23400
# 1  https://shopping-phinf.pstatic.net/main_325076...     윤인성    19800
# 2  https://shopping-phinf.pstatic.net/main_403540...     박응용    19800
# 3  https://shopping-phinf.pstatic.net/main_526155...  사이토 고키    23400
# 4  https://shopping-phinf.pstatic.net/main_324609...     홍의경    29440
#
#   publisher   pubdate           isbn  \
# 0     한빛미디어  20250214  9791169213271
# 1     한빛미디어  20220601  9791162245651
# 2   이지스퍼블리싱  20230615  9791163034735
# 3     한빛미디어  20250124  9791169213387
# 4      생능출판  20220309  9788970506784
#
#                                          description
# 0  “파이썬을 배워서 어디에 활용할 수 있을지 궁금했나요?”\n나의 신용카드 내역 분석...
# 1  혼자 해도 충분하다! 1:1 과외하듯 배우는 파이썬 프로그래밍 자습서\n\n『혼자 ...
# 2  프로그래밍 분야 8년 연속 베스트셀러!\n《Do it! 점프 투 파이썬》 전면 개정...
# 3  딥러닝 분야 부동의 베스트셀러!\n머리로 이해하고 손으로 익히는 가장 쉬운 딥러닝 ...
# 4  코딩 실력을 키우는 지름길은 실습이다.\n\n2008년 즈음에 검인정 중학교 교과서...

# %% [markdown]
# 3. 질문 : 검색어로 찾은 책 목록 출력하기

# %%
import json
import os

# 책 목록 출력 함수
def print_books(books):
    for idx, book in enumerate(books, 1):
        print(f"\n{idx}. 제목: {book.get('title')}")
        print(f"저자: {book.get('author')}")
        print(f"출판사: {book.get('publisher')}")
        print(f"가격: {book.get('price')}원")
        print(f"출간일: {book.get('pubdate')}")
        print(f"링크: {book.get('link')}")
        desc = book.get('description', '')
        print(f"설명: {desc[:100]}{'...' if len(desc) > 100 else ''}")

# JSON 파일을 읽어서 책 목록 출력
def load_and_print_books(filepath='data/books.json'):
    if not os.path.exists(filepath):
        print(f"No File: {filepath}")
        return

    with open(filepath, 'r', encoding='utf-8') as f:
        books = json.load(f)

    if books:
        print_books(books)
    else:
        print("Empty.")
        
if __name__ == '__main__':
    load_and_print_books()
# Out:
# 1. 제목: 혼자 만들면서 공부하는 파이썬 (37개 라이브러리와 API로 보고서, 차트, 게임, 맵, AI 챗봇 만들기|저자 직강 유튜브 강의, 오픈 채팅 제공)
#    저자: 문현일
#    출판사: 한빛미디어
#    가격: None원
#    출간일: 20250214
#    링크: https://search.shopping.naver.com/book/catalog/52859338841
#    설명: “파이썬을 배워서 어디에 활용할 수 있을지 궁금했나요?”
# 나의 신용카드 내역 분석, 우리 아파트 실거래가 시각화해보기, 맛집 지도 웹 앱 만들기 등
# 생활 속  15가지 파이썬 프...
#
# 2. 제목: 혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)
#    저자: 윤인성
#    출판사: 한빛미디어
#    가격: None원
#    출간일: 20220601
#    링크: https://search.shopping.naver.com/book/catalog/32507605957
#    설명: 혼자 해도 충분하다! 1:1 과외하듯 배우는 파이썬 프로그래밍 자습서
#
# 『혼자 공부하는 파이썬』이 더욱 흥미있고 알찬 내용으로 개정되었습니다. 프로그래밍이 정말 처음인 입문자도 따...
#
# 3. 제목: Do it! 점프 투 파이썬 (중학생도 첫날부터 실습하는 초고속 입문서)
#    저자: 박응용
#    출판사: 이지스퍼블리싱
#    가격: None원
#    출간일: 20230615
#    링크: https://search.shopping.naver.com/book/catalog/40354085633
#    설명: 프로그래밍 분야 8년 연속 베스트셀러!
# 《Do it! 점프 투 파이썬》 전면 개정 2판 출시!
#
# 중고등학생도, 비전공자도, 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이 전면 개...
#
# 4. 제목: 밑바닥부터 시작하는 딥러닝 1(리마스터판) (파이썬으로 익히는 딥러닝 이론과 구현)
#    저자: 사이토 고키
#    출판사: 한빛미디어
#    가격: None원
#    출간일: 20250124
#    링크: https://search.shopping.naver.com/book/catalog/52615553184
#    설명: 딥러닝 분야 부동의 베스트셀러!
# 머리로 이해하고 손으로 익히는 가장 쉬운 딥러닝 입문서
#
# 이 책은 딥러닝의 핵심 개념을 ‘밑바닥부터’ 구현해보며 기초를 한 걸음씩 탄탄하게 다질 수...
#
# 5. 제목: 파이썬
#    저자: 홍의경
#    출판사: 생능출판
#    가격: None원
#    출간일: 20220309
#    링크: https://search.shopping.naver.com/book/catalog/32460987987
#    설명: 코딩 실력을 키우는 지름길은 실습이다.
#
# 2008년 즈음에 검인정 중학교 교과서 정보1, 정보2, 정보3을 공저로 저술하였습니다. 그 당시에 8종류의 교과서가 검인정에 합격하였는데...
#
# 6. 제목: CODING BASICS PYTHON (파이썬)
#    저자: 김상민^장성식^김일태
#    출판사: 렉스미디어닷넷
#    가격: None원
#    출간일: 20220210
#    링크: https://search.shopping.naver.com/book/catalog/32440944646
#    설명: 파이썬으로 다지는 프로그래밍의 기초
#
# ㆍ 다양한 예제를 활용하여 초보자도 쉽게 프로그래밍의 기본을 익힐 수 있는 파이썬 입문서입니다.
# ㆍ 문법을 사전식으로 나열하지 않고 기능적인 ...
#
# 7. 제목: 파이썬 (제2판)
#    저자: 염기원^오지영
#    출판사: 북두
#    가격: None원
#    출간일: 20220120
#    링크: https://search.shopping.naver.com/book/catalog/32436240934
#    설명: 책의 전반부는 비전공자의 입장에서 비전공자를 위한 파이썬 프로그래밍의 기초적인 내용으로 구성되어 있다. 프로그래밍에 익숙하거나 파이썬 경험이 있는 독자들은 곧바로 책의 후반부를 공...
#
# 8. 제목: 파이썬
#    저자: 천인국
#    출판사: 인피니티북스
#    가격: None원
#    출간일: 20170830
#    링크: https://search.shopping.naver.com/book/catalog/32489150082
#    설명: 컴퓨팅 사고(Computational Thinking)는 자넷 윙 교수가 2006년에 컴퓨터 학술지에서 언급한 이후로 컴퓨터 교육 분야에서 상당한 이슈가 되고 있는 용어이다. 컴퓨...
#
# 9. 제목: 파이썬 (비전공자를위한 파이썬 기초 입문서)
#    저자: 김명호
#    출판사: 에듀웨이
#    가격: None원
#    출간일: 20190525
#    링크: https://search.shopping.naver.com/book/catalog/32436003648
#    설명: 막막했던 파이썬, 이제 한 권으로 기초를 배우는
# 파이썬 사용 설명서!
#
# 전 세계적으로 유명한 구글(Google)이 자신의 많은 서비스를 파이썬으로 제공하고 있습니다. 이것은 구글의...
#
# 10. 제목: 파이썬
#    저자: 염기원
#    출판사: 복두출판사
#    가격: None원
#    출간일: 20200820
#    링크: https://search.shopping.naver.com/book/catalog/32490271648
#    설명: 비전공자의 데이터 분석을 위한 『파이썬』은 〈파이썬 기초〉, 〈파이썬을 이용한 데이터 분석 기초〉, 〈시각화 라이브러리 사용하기〉 등 파이썬의 기초적이고 전반적인 내용이 수록되어 ...
#
# 11. 제목: 파이썬
#    저자: 김영천
#    출판사: 기한재
#    가격: None원
#    출간일: 20200225
#    링크: https://search.shopping.naver.com/book/catalog/32438172833
#    설명: ▶ 이 책은 Python(파이썬)을 다룬 이론서입니다. Python(파이썬)의 기초적이고 전반적인 내용을 학습할 수 있습니다.
#
# 12. 제목: 파이썬
#    저자: 서정원^김태령
#    출판사: 생능출판
#    가격: None원
#    출간일: 20190228
#    링크: https://search.shopping.naver.com/book/catalog/32505098970
#    설명: 이 책은 지금까지 경험하지 못한 코딩 교육의 진수를 보여준다. “코딩 교육이 가야 할 방향은 컴퓨팅 사고력을 높이는 것이다.”라고 이 책의 저자들이 말하듯, “디지털 시대에 적합한...
#
# 13. 제목: 파이썬 (다양한 예제로 알로리즘 쉽게 분석하기)
#    저자: 김유진
#    출판사: 다본
#    가격: None원
#    출간일: 20190410
#    링크: https://search.shopping.naver.com/book/catalog/32441765959
#    설명: 파이썬은 인터프리터 방식으로 접근이 쉬운 반면 다양한 기능의 라이브러리들이 제공되어 빅 데이터나 머신 러닝, 순수 과학, 웹, GUI 등 다양한 분야에서 사용되고 있다. 또한, 파...
#
# 14. 제목: 파이썬
#    저자: Y. Daniel Liang
#    출판사: 에피스테메
#    가격: None원
#    출간일: 20180302
#    링크: https://search.shopping.naver.com/book/catalog/32441653441
#    설명: 이 책은 누구나 쉽게 따라할 수 있는 파이썬 프로그래밍 언어에 기반하고 있기 때문에 프로그래밍을 통해 얻을 수 있는 논리 능력 향상과 문제 해결력 배양에 가장 적합하다.
# 비전공자...
#
# 15. 제목: 파이썬
#    저자: Y. Daniel Liang
#    출판사: 생능출판
#    가격: None원
#    출간일: 20160205
#    링크: https://search.shopping.naver.com/book/catalog/32504743740
#    설명: [파이썬]은 파이썬 언어에 대한 기본 문법부터 활용까지 프로그래밍에 관한 전반적인 내용을 다루고 있다. 이 책을 활용한 프로그래밍 학습을 통해 파이썬 프로그램을 스스로 작성하고 실...
#
# 16. 제목: 파이썬 머신러닝 완벽 가이드 (다양한 캐글 예제와 함께 기초 알고리즘부터 최신 기법까지 배우는)
#    저자: 권철민
#    출판사: 위키북스
#    가격: None원
#    출간일: 20220421
#    링크: https://search.shopping.naver.com/book/catalog/32485894885
#    설명: 자세한 이론 설명과 파이썬 실습을 통해 머신러닝을 완벽하게 배울 수 있습니다!
#
# 《파이썬 머신러닝 완벽 가이드》는 이론 위주의 머신러닝 책에서 탈피해, 다양한 실전 예제를 직접 구...
#
# 17. 제목: 내공의 파이썬 (한 권으로 끝내는 초보자용 코딩 입문서)
#    저자: 한선관
#    출판사: 자유아카데미
#    가격: None원
#    출간일: 20250315
#    링크: https://search.shopping.naver.com/book/catalog/53550577590
#    설명: 『내공의 파이썬』은 파이썬을 처음 접하는 독자들이 기본 개념을 쉽게 익히고, 점진적으로 내공의 실력을 쌓을 수 있도록 구성하였다. 단순한 문법 암기에 그치지 않고, 실제 코딩에 적...
#
# 18. 제목: 독학 파이썬
#    저자: 야마다 요시히로
#    출판사: 정보문화사
#    가격: None원
#    출간일: 20241220
#    링크: https://search.shopping.naver.com/book/catalog/51981118640
#    설명: 이론과 실전이 모두 담긴 단 한 권의 파이썬 교과서
#
# 처음 파이썬 프로그래밍을 시작하는 사람 또는 더욱 깊은 내용을 목표로 하는 사람에게 정확한 지식을 제공하기 위해 쓰였다. 파이...
#
# 19. 제목: 파이썬 마스터 (실생활 융합 예제로 배우는)
#    저자: 김종훈^김동건
#    출판사: 한빛아카데미
#    가격: None원
#    출간일: 20250117
#    링크: https://search.shopping.naver.com/book/catalog/52509305501
#    설명: 파이썬 프로그래밍 기초와 데이터 분석을
# 한 권으로 마스터하는 파이썬 기본서!
#
# 『파이썬 마스터』는 파이썬을 처음 배우는 독자를 대상으로 하는 책이며, 파이썬의 기초 문법부터 넘파이...
#
# 20. 제목: 파이썬 워크북
#    저자: 안기수
#    출판사: 생능출판
#    가격: None원
#    출간일: 20250115
#    링크: https://search.shopping.naver.com/book/catalog/52417646624
#    설명: 파이썬 언어의 가장 큰 특징은 문법이 간결하여 배우기 쉽다는 것이다. 그러나 이미 만들어진 프로그램이나 어플을 단지 활용만 해보다가 그 프로그램이 어떤 언어로 만들어진 것인지, 그...
#
# 21. 제목: 코딩 자율학습 나도코딩의 파이썬 입문 (초보자 눈높이에 맞춘 친절한 프로그래밍 자습서)
#    저자: 나도코딩
#    출판사: 길벗
#    가격: None원
#    출간일: 20230220
#    링크: https://search.shopping.naver.com/book/catalog/37828235624
#    설명: 30만 명의 구독자와 2만 6천 명의 수강생이 증명한 최고의 파이썬 강의
# 나도코딩의 프로그래밍 학습 노하우를 배우자!
#
# 유튜브와 인프런 최고의 인기 강의를 한 권에 담았습니다. 일...
#
# 22. 제목: 파이썬 3 (프로그래밍을 배우기에 가장 재미있는 언어)
#    저자: 박상현
#    출판사: 한빛미디어
#    가격: None원
#    출간일: 20160210
#    링크: https://search.shopping.naver.com/book/catalog/32485534946
#    설명: 본서는 프로그래밍 경험이 없는 독자가 파이썬을 통해 프로그래밍을 배워볼 수 있는 입문서로서, 프로그래밍을 배우고 싶지만 두려움이 있는 입문자에게 가장 적합한 난이도로 설명한다.
#
# 23. 제목: 파이썬 + AI (코드조각과 실행화면으로 배우는 코딩)
#    저자: 안용제^김남규
#    출판사: 디지털북스
#    가격: None원
#    출간일: 20240715
#    링크: https://search.shopping.naver.com/book/catalog/48703888619
#    설명: “코드조각과 실행화면을 통해, 단계적 반복을 통해 배우는 파이썬과 AI”
#
# 이 책은 프로그래밍 언어에 익숙한 프로그래머가 아닌 프로그램 입문자들을 대상으로 프로그래밍에 대해 아무런...
#
# 24. 제목: 으뜸 파이썬 (개정판)
#    저자: 박동규^강영민
#    출판사: 생능출판
#    가격: None원
#    출간일: 20240614
#    링크: https://search.shopping.naver.com/book/catalog/48359296619
#    설명: 이 책의 구성
# 초판과 마찬가지로 이 책은 대학에서 교양 과정 수강생과 전공자들이 쉽게 프로그래밍을 접하고 흥미를 가질 수 있도록 구성하였다. 이를 위하여 파이썬 설치부터 기초적인 ...
#
# 25. 제목: 파이썬 프로그래밍 (기초부터 딥러닝까지)
#    저자: 허준
#    출판사: 성안당
#    가격: None원
#    출간일: 20250312
#    링크: https://search.shopping.naver.com/book/catalog/53415634237
#    설명: ■ 책의 특징
# 1. 기초부터 심화까지 체계적인 학습 제공
# 파이썬의 기본 문법과 데이터 타입 등 기초적인 내용을 시작으로, 반복문, 함수, 파일 입출력 등 프로그래밍의 핵심 개념을...
#
# 26. 제목: 이지파이썬 1 (그림과 스토리텔링으로 이해하는 쉽고 재미있는 파이썬)
#    저자: 한국인공지능아카데미
#    출판사: 클라우드북스
#    가격: None원
#    출간일: 20240901
#    링크: https://search.shopping.naver.com/book/catalog/49922621623
#    설명: "이지 파이썬"은 프로그래밍 초보자를 위해 만든 쉽고 친근한 파이썬 입문서입니다. 재미있는 상황과 그림으로 프로그래밍 개념을 설명하고, 그 개념들이 상황과 함께 기억에 남도록 합니...
#
# 27. 제목: 이지파이썬 2 (그림과 스토리텔링으로 이해하는 쉽고 재미있는 파이썬)
#    저자: 한국인공지능아카데미
#    출판사: 클라우드북스
#    가격: None원
#    출간일: 20240901
#    링크: https://search.shopping.naver.com/book/catalog/49926240618
#    설명: "이지 파이썬"은 프로그래밍 초보자를 위해 만든 쉽고 친근한 파이썬 입문서입니다. 재미있는 상황과 그림으로 프로그래밍 개념을 설명하고, 그 개념들이 상황과 함께 기억에 남도록 합니...
#
# 28. 제목: 이지파이썬 1 (그림과 스토리텔링으로 이해하는 쉽고 재미있는 파이썬)
#    저자: 한국인공지능아카데미
#    출판사: 클라우드북스
#    가격: None원
#    출간일: 20240901
#    링크: https://search.shopping.naver.com/book/catalog/49922615621
#    설명: "이지 파이썬"은 프로그래밍 초보자를 위해 만든 쉽고 친근한 파이썬 입문서입니다. 재미있는 상황과 그림으로 프로그래밍 개념을 설명하고, 그 개념들이 상황과 함께 기억에 남도록 합니...
#
# 29. 제목: 파이썬 플러스
#    저자: 최희식
#    출판사: 인피니티북스
#    가격: None원
#    출간일: 20240731
#    링크: https://search.shopping.naver.com/book/catalog/49800327644
#    설명: 파이썬 최신 버전 반영!
# 파이썬을 마스터하고 싶은 학습자들의 필독서!
#
# 『핵심코어! 파이썬 프로그래밍』이 더욱 알찬 구성으로 업데이트되어 새로운 책으로 돌아왔다. 『파이썬 플러스』...
#
# 30. 제목: 엑셀X파이썬 (엑셀이 파이썬을 품었다)
#    저자: 정성일
#    출판사: 길벗
#    가격: None원
#    출간일: 20240730
#    링크: https://search.shopping.naver.com/book/catalog/49255941621
#    설명: 엑셀이 파이썬을 품었다
#
# MS 365 엑셀에 파이썬을 통합하는 강력한 기능이 업데이트되었다. 이제 엑셀의 셀에 ‘=PY’ 함수를 입력하면 파이썬 코드를 직접 실행할 수 있다. 별도...
#
# 31. 제목: 파이썬 강좌
#    저자: 류주환
#    출판사: 퍼플
#    가격: None원
#    출간일: 20230327
#    링크: https://search.shopping.naver.com/book/catalog/39215805619
#    설명: 파이썬은 확장성과 능력이 큰 컴퓨터 언어이다. 이 책은 파이썬의 설치의 안내부터 시작해서 기본문법을 빠르게 습득하도록 의도하였다. 그 과정에서 항상 실제 프로그램을 작성하고 이용하...
#
# 32. 제목: 파이썬 연습 (개정판)
#    저자: 김기용
#    출판사: 그린
#    가격: None원
#    출간일: 20220225
#    링크: https://search.shopping.naver.com/book/catalog/32436138278
#    설명: 『파이썬 연습』은 파이썬에 대해 다룬 도서이며 〈프로그래밍과 파이썬〉, 〈숫자,문자열,변수,계산하기〉, 〈논리연산과 조건문〉 등을 수록하고 있어 기초적이고 전반적인 내용을 확인하실...
#
# 33. 제목: 안녕, 파이썬
#    저자: 김학인
#    출판사: 북랩
#    가격: None원
#    출간일: 20220314
#    링크: https://search.shopping.naver.com/book/catalog/32487126181
#    설명: 직관적이고 간결한 프로그래밍 언어, 파이썬
# 코딩 입문자라면 망설이지 말고 파이썬으로 시작하자
#
# 비전공자와 초보자를 프로그래밍의 세계로 안내해줄
# 친절하고 재밌는 파이썬 입문서
#
# 4차...
#
# 34. 제목: 파이썬 정복 (파이썬 개발에 필요한 기본 지식을 모두 담은 파이썬 입문서)
#    저자: 김상형
#    출판사: 한빛미디어
#    가격: None원
#    출간일: 20180402
#    링크: https://search.shopping.naver.com/book/catalog/32472371886
#    설명: 프로그래밍을 처음 접하는 독자를 위한 파이썬 입문서(쉽게, 깊이 있게, 그리고 재미있게)
#
# 어떤 독자를 위한 책인가?
#
# -. 프로그래밍을 전혀 경험해보지 못한 일반인
# -. 파이...
#
# 35. 제목: 클린 파이썬 (효과적인 파이썬 코딩 기법)
#    저자: 수닐 카필
#    출판사: 에이콘출판
#    가격: None원
#    출간일: 20210416
#    링크: https://search.shopping.naver.com/book/catalog/32473884666
#    설명: 파이썬을 더 나은 방법으로 코딩할 수 있도록 팁과 방법을 알려주는 지침서다. 파이썬의 내장 데이터 구조, 함수와 클래스, 딕셔너리, 모듈 및 메타 클래스, 데코레이터와 컨텍스트 매...
#
# 36. 제목: 파이썬 입문 (3step으로 확실하게 배우는)
#    저자: 야마다 요시히로^야마다 나미
#    출판사: 시그마프레스
#    가격: None원
#    출간일: 20210105
#    링크: https://search.shopping.naver.com/book/catalog/32503438758
#    설명: 가장 쉬운 파이썬 입문서
# 프로그래밍의 기본을 알기 쉽게 해설하다!
#
# 파이썬은 심플하지만 본격적인 애플리케이션을 만들 수 있는 언어이다. 구글이나 유튜브에서부터 최근에는 기계학습이나...
#
# 37. 제목: 그림으로 정리한 알고리즘과 자료구조 (자바 + 파이썬)
#    저자: 조민호
#    출판사: 정보문화사
#    가격: None원
#    출간일: 20180810
#    링크: https://search.shopping.naver.com/book/catalog/32506021644
#    설명: 세상을 이해하는 중요한 기준인 알고리즘과 자료구조의 모든 개념과 아이디어를 그림으로 표현하여 쉽게 이해할 수 있도록 하였고, 각 알고리즘과 자료구조의 원리를 자바와 파이썬 코드로 ...
#
# 38. 제목: ELS 평가를 위한 몬테카를로 시뮬레이션과 유한차분법 파이썬 활용 (파이썬 활용)
#    저자: 한현수^김상권^유민현^이원진^류지상
#    출판사: 지오북스
#    가격: None원
#    출간일: 20191101
#    링크: https://search.shopping.naver.com/book/catalog/32461140654
#    설명: ▶ 이 책은 전산통계/수치해석을 다룬 이론서입니다. 전산통계/수치해석의 기초적이고 전반적인 내용을 학습할 수 있습니다
#
# 39. 제목: 25시간만에 배우는 머신러닝 예제 (파이썬 활용)
#    저자: 김준석^김상권
#    출판사: 이모션미디어
#    가격: None원
#    출간일: 20180131
#    링크: https://search.shopping.naver.com/book/catalog/32456860663
#    설명: ▶ 이 책은 25시간만에 배우는 머신러닝 예제에 대해 다룬 도서입니다. 머신러닝 예제의 기초적이고 전반적인 내용을 확인할 수 있도록 구성했습니다.
#
# 40. 제목: 파이썬의 신 (프로그래밍 언어를 배운다는 것)
#    저자: 김주현
#    출판사: 로드북
#    가격: None원
#    출간일: 20161223
#    링크: https://search.shopping.naver.com/book/catalog/32492206933
#    설명: 체계적으로 프로그래밍 기초를 쌓을 수 있는 입문서다. 특히 파이썬은 다중패러다임 언어인 만큼, 이 책에서는 독자가 객체지향이든 함수형이든 그 의미를 파악하여 유연한 프로그래머가 될...
#
# 41. 제목: 파이썬 연습
#    저자: 김기용
#    출판사: 그린
#    가격: None원
#    출간일: 20200227
#    링크: https://search.shopping.naver.com/book/catalog/32490324873
#    설명: ▶ 이 책은 Python(파이썬)을 다룬 이론서입니다. Python(파이썬)의 기초적이고 전반적인 내용을 학습할 수 있습니다.
#
# 42. 제목: 으뜸 파이썬 (프로그래밍을 사랑하는 두 교수가 작정하고 쓴)
#    저자: 박동규^강영민
#    출판사: 생능출판
#    가격: None원
#    출간일: 20200217
#    링크: https://search.shopping.naver.com/book/catalog/32496549634
#    설명: [이 책의 특징]
# 첫째, 파이썬의 기초를 익히고자 하는 초급자들이 쉽게 코딩의 원리를 이해하도록 돕기 위해 짧은 코드는 대화창에서 그 기능을 보여주며, 다소 긴 코드는 스크립트 파...
#
# 43. 제목: 자기주도 파이썬 (혼자서도 쉽게 익힐 수 있는, 제4판)
#    저자: 한컴에듀케이션 알고리즘연구소
#    출판사: 복두출판사
#    가격: None원
#    출간일: 20240805
#    링크: https://search.shopping.naver.com/book/catalog/49800339741
#    설명: 필자가 “자기주도 C언어 프로그래밍”이라는 책을 선보인지 어느덧 14년이 넘었다. 처음에는 기존의 프로그래밍 도서와 전혀 다른 스타일 때문에 별로 주목받지 못하다가 점차적으로 관심...
#
# 44. 제목: 파이썬 올인원 (기초부터 데이터분석까지)
#    저자: 이지민^임희경
#    출판사: 연두에디션
#    가격: None원
#    출간일: 20230904
#    링크: https://search.shopping.naver.com/book/catalog/42377563630
#    설명: 현재 우리가 사는 시대는 컴퓨터가 주도하고 있다고 말할 수 있는 시기입니다. 특히 인공지능 시대가 도래하면서 컴퓨터를 움직이는 요소인 소프트웨어를 만들고 다룰 수 있는 코딩 능력은...
#
# 45. 제목: 달구나 파이썬! (개정판)
#    저자: 노순국^이금분^정유정
#    출판사: 연두에디션
#    가격: None원
#    출간일: 20230815
#    링크: https://search.shopping.naver.com/book/catalog/42326876627
#    설명: 최근 전 세계는 4차산업 혁명시대를 맞이하여 소프트웨어(Software)가 새로운 가치 창출의 중심으로 급부상함에 따라 소프트웨어 중심사회로 변화하고 있고, 더욱이 인공지능(Art...
#
# 46. 제목: 파이썬을 이용한 통계수학
#    저자: 권세혁
#    출판사: 자유아카데미
#    가격: None원
#    출간일: 20250315
#    링크: https://search.shopping.naver.com/book/catalog/53550577579
#    설명: 데이터 사이언스에 필요한 수학 개념과 이론의 실용적 활용에 중점을 두었다. 특히, 수학 개념이 데이터 분석 과정에서 어떻게 응용되는지를 다양한 예제를 통해 살펴보고, Python을...
#
# 47. 제목: 파이썬 프로그래밍 (기초부터 실전까지 한 권에 끝내는, 개정판)
#    저자: 박영권
#    출판사: 시대인
#    가격: None원
#    출간일: 20241010
#    링크: https://search.shopping.naver.com/book/catalog/50497379626
#    설명: 파이썬 핵심 문법과 다양한 실전 프로그래밍을 경험할 수 있다!
# 이 책은 파이썬 입문자와 파이썬 프로그래밍에 대한 개념 정립이 필요한 독자를 대상으로 하며, 파이썬 기초부터 활용까...
#
# 48. 제목: 파이썬의 정석
#    저자: 조용주^임좌상
#    출판사: 길벗캠퍼스
#    가격: None원
#    출간일: 20230110
#    링크: https://search.shopping.naver.com/book/catalog/36925491630
#    설명: 프로그래밍 입문자를 위한 파이썬의 입문 가이드
#
# 4차 산업혁명의 핵심인 머신러닝, 사물 인터넷(IoT), 데이터 분석 등 다양한 분야에 활용되는
# 직관적이고 간결한 문법의 파이썬 프...
#
# 49. 제목: 새내기 파이썬
#    저자: 천인국
#    출판사: 생능출판
#    가격: None원
#    출간일: 20220630
#    링크: https://search.shopping.naver.com/book/catalog/33084056619
#    설명: 파이썬은 현재 가장 각광받는 언어라고 말할 수 있다. 최근에 인공지능이나 데이터 과학, 영상처리, 업무 자동화 분야는 파이썬으로 프로그램을 작성하는 것이 거의 표준으로 되어 있다....
#
# 50. 제목: 디딤돌 파이썬 (구조적 프로그래밍으로 설명한 파이썬 기초)
#    저자: 이찬수
#    출판사: 인피니티북스
#    가격: None원
#    출간일: 20220823
#    링크: https://search.shopping.naver.com/book/catalog/34233217628
#    설명: 이 책은 파이썬의 고유한 문법이나 그에 대한 활용보다는, 파이썬 언어를 기반으로 한 컴퓨터 프로그래밍과 문제해결에 비중을 두고 있다. 이를 위해 일반적인 파이썬 학습 순서와는 달리...

# %% [markdown]
# 4. 질문 : 검색어로 찾은 책 목록 중에서 가격이 2만원 이상인 책만 출력하기

# %%
import json
import pandas as pd

def print_filtered_books(filepath='data/books.json'):
    with open(filepath, 'r', encoding='utf-8') as f:
        books = json.load(f)

    # JSON 리스트 → DataFrame
    df = pd.DataFrame(books)

    # discount 컬럼을 숫자형으로 변환
    df['discount'] = pd.to_numeric(df['discount'], errors='coerce')

    # 조건 필터: discount >= 20000
    filtered_df = df[df['discount'] >= 20000]

    # 필요한 컬럼만 선택
    filtered_df = filtered_df[['title', 'author', 'discount', 'publisher', 'pubdate']]

    # discount 기준으로 내림차순 정렬
    filtered_df = filtered_df.sort_values(by='discount', ascending=False)

    # 인덱스 초기화
    filtered_df = filtered_df.reset_index(drop=True)

    print(filtered_df)

# 실행
if __name__ == '__main__':
    print_filtered_books()
# Out:
#                                                 title           author  \
# 0                   으뜸 파이썬 (프로그래밍을 사랑하는 두 교수가 작정하고 쓴)          박동규^강영민
# 1                                                 파이썬  Y. Daniel Liang
# 2                                        으뜸 파이썬 (개정판)          박동규^강영민
# 3                            파이썬 마스터 (실생활 융합 예제로 배우는)          김종훈^김동건
# 4   파이썬 머신러닝 완벽 가이드 (다양한 캐글 예제와 함께 기초 알고리즘부터 최신 기법...              권철민
# 5                                                 파이썬              홍의경
# 6                                              독학 파이썬         야마다 요시히로
# 7                                             새내기 파이썬              천인국
# 8                                             파이썬의 정석          조용주^임좌상
# 9                    디딤돌 파이썬 (구조적 프로그래밍으로 설명한 파이썬 기초)              이찬수
# 10                     파이썬 + AI (코드조각과 실행화면으로 배우는 코딩)          안용제^김남규
# 11                          파이썬의 신 (프로그래밍 언어를 배운다는 것)              김주현
# 12                    내공의 파이썬 (한 권으로 끝내는 초보자용 코딩 입문서)              한선관
# 13                                            파이썬 플러스              최희식
# 14                                                파이썬              김영천
# 15     밑바닥부터 시작하는 딥러닝 1(리마스터판) (파이썬으로 익히는 딥러닝 이론과 구현)           사이토 고키
# 16                                       파이썬 연습 (개정판)              김기용
# 17  혼자 만들면서 공부하는 파이썬 (37개 라이브러리와 API로 보고서, 차트, 게임,...              문현일
# 18                             파이썬 프로그래밍 (기초부터 딥러닝까지)               허준
# 19                              엑셀X파이썬 (엑셀이 파이썬을 품었다)              정성일
# 20                          파이썬 입문 (3step으로 확실하게 배우는)  야마다 요시히로^야마다 나미
# 21                         파이썬 (다양한 예제로 알로리즘 쉽게 분석하기)              김유진
# 22   코딩 자율학습 나도코딩의 파이썬 입문 (초보자 눈높이에 맞춘 친절한 프로그래밍 자습서)             나도코딩
# 23                                      파이썬을 이용한 통계수학              권세혁
# 24                             파이썬 올인원 (기초부터 데이터분석까지)          이지민^임희경
#
#     discount publisher   pubdate
# 0      31680      생능출판  20200217
# 1      31500     에피스테메  20180302
# 2      31280      생능출판  20240614
# 3      31040    한빛아카데미  20250117
# 4      29800      위키북스  20220421
# 5      29440      생능출판  20220309
# 6      28800     정보문화사  20241220
# 7      27600      생능출판  20220630
# 8      26820     길벗캠퍼스  20230110
# 9      26100    인피니티북스  20220823
# 10     25200     디지털북스  20240715
# 11     24300       로드북  20161223
# 12     24300    자유아카데미  20250315
# 13     23750    인피니티북스  20240731
# 14     23750       기한재  20200225
# 15     23400     한빛미디어  20250124
# 16     23400        그린  20220225
# 17     23400     한빛미디어  20250214
# 18     22500       성안당  20250312
# 19     22500        길벗  20240730
# 20     22500    시그마프레스  20210105
# 21     22500        다본  20190410
# 22     21600        길벗  20230220
# 23     21560    자유아카데미  20250315
# 24     20700     연두에디션  20230904

# %% [markdown]
# 5. 질문 : 검색어로 찾은 책 목록 중에서 출판사가 인피니티북스인 책만 출력하기

# %%
import json
import pandas as pd

def print_books_by_infinitybooks(filepath='data/books.json'):
    with open(filepath, 'r', encoding='utf-8') as f:
        books = json.load(f)

    # JSON 리스트 → DataFrame
    df = pd.DataFrame(books)

    # 필터링: 출판사 == "인피니티북스"
    filtered_df = df[df['publisher'] == '인피니티북스']

    # image, description 컬럼 제거 (있을 때만)
    filtered_df = filtered_df.drop(columns=['image', 'description'], errors='ignore')

    # 인덱스 초기화
    filtered_df = filtered_df.reset_index(drop=True)

    print(filtered_df)

# 실행
if __name__ == '__main__':
    print_books_by_infinitybooks()
# Out:
#                               title  \
# 0                               파이썬
# 1                           파이썬 플러스
# 2  디딤돌 파이썬 (구조적 프로그래밍으로 설명한 파이썬 기초)
#
#                                                 link author discount  \
# 0  https://search.shopping.naver.com/book/catalog...    천인국    12000
# 1  https://search.shopping.naver.com/book/catalog...    최희식    23750
# 2  https://search.shopping.naver.com/book/catalog...    이찬수    26100
#
#   publisher   pubdate           isbn
# 0    인피니티북스  20170830  9791185578330
# 1    인피니티북스  20240731  9791192373362
# 2    인피니티북스  20220823  9791192373058
